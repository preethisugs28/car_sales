# %% [markdown]
# # Exploratory Data Analysis (EDA) for Car Sales

# %% [markdown]
# # Problem Statement
#
#
# Use basics understanding of Pandas,matplotlib and Seaborn and the basic commands of (EDA) which includes cleaning, munging, combining, reshaping, slicing, dicing, and transforming data for analysis purpose.
#
# Exploratory Data Analysis on 'New Car Sales' data Analyzing the car sales data with :
# * Finding patterns in Data
# * Determining relationships in Data
# * Checking of assumptions

# %% [markdown]
# # Description of the dataset
#
# * The dataset consists of the information about different car sales in over a period of time. Various variables present in the dataset includes data of car, model, price, drive etc.
# * The dataset comprises of 9576 observations of 10 columns. Below is a table showing names of all the columns and their description.

# %% [markdown]
# Column Name	Description
#
# * Car	Car brand name
# * model	Available car different Variants
# * year	purchasing Year
# * body	Body type-Hatchback, Sedan, Crossover etc
# * mileage	car Mileage
# * engV	Engine version
# * engType	Car Fuel type - Petrol, Diesel, gas etc
# * drive	Wheel Drive Front, back
# * registration
# * Check if the vechile is registered
# * price	Price of Car in $

# %% [markdown]
# # 1.Importing packages

# %%
import numpy as np                                                 
import pandas as pd                                         
import pandas_profiling
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns                                              # Provides a high level interface for drawing attractive and informative statistical graphics
# %matplotlib inline
sns.set()

from subprocess import check_output
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# !pip install plotly --upgrade
# Out:
# ...
#      |████████████████████████████████| 12.9MB 81kB/s eta 0:00:011
# ...
#   Found existing installation: plotly 4.8.2
#     Uninstalling plotly-4.8.2:
#       Successfully uninstalled plotly-4.8.2
# ...

# %% [markdown]
# # 2.Importing the Dataset

# %%
csales = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv", engine='python', encoding='latin-1')     # Importing car_sale dataset using pd.read_csv

# %%
csales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# # 3. Data Profiling

# %% [markdown]
# # 3.1 Rename Columns name

# %%
csales.rename(columns={'car':'brand','year':'prod_year'},inplace=True) 
csales.shape
# Out:
# (9576, 10)

# %% [markdown]
# # 3.2 Removal of Duplicates

# %%
csales.drop_duplicates(keep=False, inplace=True)           # Removing duplicate rows
csales.shape
# Out:
# (9375, 10)

# %%
import numpy as np                     

import pandas as pd

# %%
import io
import requests

# %%
url="https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv"
read_data=requests.get(url).content
read_data
# Out:
# b'car,price,body,mileage,engV,engType,registration,year,model,drive\r\nFord,15500,crossover,68,2.5,Gas,yes,2010,Kuga,full\r\nMercedes-Benz,20500,sedan,173,1.8,Gas,yes,2011,E-Class,rear\r\nMercedes-Benz,35000,other,135,5.5,Petrol,yes,2008,CL 550,rear\r\nMercedes-Benz,17800,van,162,1.8,Diesel,yes,2012,B 180,front\r\nMercedes-Benz,33000,vagon,91,NA,Other,yes,2013,E-Class,\r\nNissan,16600,crossover,83,2,Petrol,yes,2013,X-Trail,full\r\nHonda,6500,sedan,199,2,Petrol,yes,2003,Accord,front\r\nRenault,10500,vagon,185,1.5,Diesel,yes,2011,Megane,front\r\nMercedes-Benz,21500,sedan,146,1.8,Gas,yes,2012,E-Class,rear\r\nMercedes-Benz,22700,sedan,125,2.2,Diesel,yes,2010,E-Class,rear\r\nNissan,20447.154,crossover,0,1.2,Petrol,yes,2016,Qashqai,front\r\nMercedes-Benz,20400,sedan,190,1.8,Gas,yes,2011,E-Class,rear\r\nMercedes-Benz,22500,sedan,164,1.8,Gas,yes,2012,E-Class,rear\r\nBMW,4700,sedan,200,NA,Petrol,yes,1996,316,rear\r\nMercedes-Benz,21500,sedan,159,1.8,Gas,yes,2012,E-Class,rear\r\nBMW,19999,seda
# ...

# %%
csales = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv", encoding='cp1252') 
csales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
csales.dtypes     # This will print datatypes of all columns
# Out:
# car              object
# price           float64
# body             object
# mileage           int64
# engV            float64
# engType          object
# registration     object
# year              int64
# model            object
# drive            object
# dtype: object

# %%
csales.describe(include = 'all')  # This will display statistical information of dataset
# Out:
#                car          price   body      mileage         engV engType  \
# count         9576    9576.000000   9576  9576.000000  9142.000000    9576
# unique          87            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   15633.317316    NaN   138.862364     2.646344     NaN
# std            NaN   24106.523436    NaN    98.629754     5.927699     NaN
# min            NaN       0.000000    NaN     0.000000     0.100000     NaN
# 25%            NaN    4999.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9200.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   16700.000000    NaN   194.000000     2.500000     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %%
csales.columns         # This will print name of all columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
csales.head()                                          # This will print top 5 rows of dataset
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
csales.tail()                                         # This will print last 5 rows of dataset
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# 9571  2011     Tucson  front
# 9572  1986  Passat B2  front
# 9573  2008     ML 350   full
# 9574  2008     ES 350  front
# 9575  2007         Q7   full

# %%
csales.info()                                        # This will show index, data type and memory information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
csales.isnull().sum()                                # This will print count of NaN values in column
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %% [markdown]
# # 3.3 Pre Profiling of Data

# %%
csales['price'].astype(bool).sum(axis=0)          # This will print count of all non zero values in column
# Out:
# 9309

# %%
csales['price'] = csales['price'].replace(0,np.nan)   # This will replace zero value with NaN

# %%
csales['price'].fillna(csales.groupby('car')['price'].transform('mean'),inplace=True)  # This will replace NaN with mean

# %%
csales[csales['price'].isnull()]     # Check the observation for NaN value after replacing
# Out:
#          car  price   body  mileage  engV engType registration  year  model  \
# 8824  Fisker    NaN  other      100   NaN   Other          yes  2001  Karma
#
#      drive
# 8824   NaN

# %%
csales.drop(csales[csales['price'].isnull()].index, inplace = True)     # This will drop the observation which has null value of price

# %%
csales['mileage'].astype(bool).sum(axis=0)  # This will print count of all non zero values in column
# Out:
# 9227

# %%
csales.columns = map(str.lower, csales.columns)                                 
csales.dtypes
# Out:
# car              object
# price           float64
# body             object
# mileage           int64
# engv            float64
# engtype          object
# registration     object
# year              int64
# model            object
# drive            object
# dtype: object

# %%
csales['engv'].fillna(csales['engv'].mean(), inplace=True)       # This will replace NaN with mean

# %%
csales.isnull().sum()  # This will print count of NaN values in column
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engv              0
# engtype           0
# registration      0
# year              0
# model             0
# drive           510
# dtype: int64

# %% [markdown]
# # 3.4 Post Profiling of Data

# %%
postprofile = pandas_profiling.ProfileReport(csales)
postprofile.to_file(outputfile="cardata_after_preprocessing.html")

# %% [markdown]
# * Here, we have done Pandas Profiling before preprocessing our dataset, so we have named the html file as csales_before_preprocessing.html. We can find useful insight by analyzing this file.
# Now we will process our data to better understand it.

# %%
csales.describe(include='all')      # This will display statistical information of dataset
# Out:
#                car          price   body      mileage         engv engtype  \
# count         9575    9575.000000   9575  9575.000000  9575.000000    9575
# unique          86            NaN      6          NaN          NaN       4
# top     Volkswagen            NaN  sedan          NaN          NaN  Petrol
# freq           936            NaN   3646          NaN          NaN    4379
# mean           NaN   16278.477260    NaN   138.866423     2.646344     NaN
# std            NaN   24189.385033    NaN    98.634105     5.792103     NaN
# min            NaN     259.350000    NaN     0.000000     0.100000     NaN
# 25%            NaN    5500.000000    NaN    70.000000     1.600000     NaN
# 50%            NaN    9700.000000    NaN   128.000000     2.000000     NaN
# 75%            NaN   17555.000000    NaN   194.000000     2.646344     NaN
# max            NaN  547800.000000    NaN   999.000000    99.990000     NaN
#
#        registration         year    model  drive
# ...

# %% [markdown]
# # 3.5 Preprocessing of Data

# %%
csales.drop(['model'], axis=1, inplace=True)                        # Droping column model
csales.head(5)
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year  drive
# 0  2010   full
# 1  2011   rear
# 2  2008   rear
# 3  2012  front
# 4  2013    NaN

# %%
sns.barplot(csales['car'],csales['mileage'])

# %%
sns.jointplot(csales['price'],csales['year'])

# %% [markdown]
# # Which body segment of cars sold the most ?

# %%
csales['body'].value_counts().plot.bar()
colors = ["#00e600", "#ff8c1a","#a180cc"]     # Bar chart for car 'body' variable
plt.title("Cars sold by body")
plt.ylabel('Number of vehicles')
plt.xlabel('Body type')
# Out:
# Text(0.5, 0, 'Body type')

# %%
(csales['body'].value_counts() / len(csales)*100).plot.bar()                # Bar chart of car 'body in terms of %'
plt.title("Body type bar diagram")
plt.ylabel('% of vehicles')
plt.xlabel('Body type');

# %%
csales.body.value_counts().plot.pie(autopct='%1.1f%%',subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12b319150>],
#       dtype=object)

# %% [markdown]
# # List out the top 10 brand depends on car sale?

# %%
csales.car.value_counts().head(10).plot.bar()
plt.title("Top 10 car brands on sale")
# Out:
# Text(0.5, 1.0, 'Top 10 car brands on sale')

# %%
csales[csales.price.isin(csales.price.nlargest())].sort_values(['car','model','body','mileage','price'])
# Out:
#                 car     price       body  mileage  engv engtype registration  \
# 4134        Bentley  449999.0  crossover        0  6.00  Petrol          yes
# 1611        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 7914        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 7621        Bentley  547800.0      sedan        0  6.75  Petrol          yes
# 5849  Mercedes-Benz  300000.0      other       37  5.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan       68  6.00  Petrol          yes
#
#       year     model drive
# 4134  2016  Bentayga  full
# 1611  2016  Bentayga  full
# 7914  2016  Bentayga  full
# 7621  2016  Mulsanne  rear
# 5849  2012     G 500  full
# 4325  2011     S 600   NaN

# %%
csales[csales.price.isin(csales.price.nsmallest())].sort_values(['car','model','body','mileage','price'])
# Out:
#                 car    price   body  mileage      engv engtype registration  \
# 5010            GAZ  259.350  sedan        1  2.400000   Other          yes
# 6457  Moskvich-AZLK  280.000  sedan       99  1.500000  Petrol          yes
# 7566  Moskvich-AZLK  350.000  sedan      100  2.646344   Other          yes
# 4905            VAZ  389.025  vagon        1  1.300000  Petrol          yes
# 8252            ZAZ  370.500  sedan        3  1.100000  Petrol          yes
#
#       year model drive
# 5010  1959    21  rear
# 6457  1976  2140  rear
# 7566  1985  2140   NaN
# 4905  1983  2102   NaN
# 8252  1989   968  rear

# %% [markdown]
# # Which drive segment of cars in which body type sold the most ?

# %%
sns.countplot(y='body',data=csales, hue='drive')
plt.title("Body Type v/s Drive Type")
plt.ylabel('Body Type')
plt.xlabel('Count of vehicles');

# %%
csales['price'].min()                           # minimum price
# Out:
# 259.35

# %%
csales['price'].max()                           # maximum price
# Out:
# 547800.0

# %%
csales['price_group'] = pd.cut(csales['price'],[0,20000,40000,60000,80000,100000,600000], 
                                labels = ['<20K','20-39K','40-59K','60-79K','80-99K','>100K'], include_lowest = True)
csales['price_group'] = csales['price_group'].astype(object)

# %% [markdown]
# # Which drive segment of cars in which body type sold the most ?

# %%
sns.countplot(y='body', data=csales, orient='h', hue='registration')
plt.title("Most preferred body type used in 1983-2016")
# Out:
# Text(0.5, 1.0, 'Most preferred body type used in 1983-2016')

# %%
import bokeh                           # interactive visualization library for Python
import sys                             
import os
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(8,5))
colors = ["#00e600", "#ff8c1a","#a180cc"]# Average price of vehicles by body type and drive type
sns.barplot(x="body", y="price",hue="drive", palette=colors, data=csales)
ax.set_title("Average price of cars by body type and drive type",fontdict= {'size':12})
ax.xaxis.set_label_text("Body Type Of Car",fontdict= {'size':12})
ax.yaxis.set_label_text("Average Price",fontdict= {'size':12})
plt.show()

# %% [markdown]
# sns.countplot(y='price_group',data=csales, hue='drive', order=['<20K','20-39K','40-59K','60-79K','80-99K','>100K'])
# plt.title("Price Group v/s Drive Type")
# plt.ylabel('Price Group')
# plt.xlabel('Count of vehicles');

# %%
carprc = csales.loc[csales['price'] >= 100000]
(carprc['car'].value_counts() / len(carprc)*100).plot.bar()                
plt.title("Brand wise Sales Distribution in Higher Price Segment")
plt.ylabel('% of vehicles')
plt.xlabel('car type');

# %%
sns.factorplot(y='price_group', data=csales, hue='engtype', kind= 'count', order=['<20K','20-39K','40-59K','60-79K','80-99K','>100K'])   
plt.title('Factorplot for Price Group and Engine Type')
plt.ylabel('Price Group')
plt.xlabel('Count of vehicles');             # Price group v/s engType

# %%
carengine = csales.loc[csales['engv'] <= 6]
carengine['engv'].value_counts().sort_index().plot.line()       # engine volume wise count of vehicles
plt.title("Engine Volume (CC) wise count of vehicles")
plt.ylabel('Count of vehicles')
plt.xlabel('Engine Volume');
plt.xlim(0,6)
# Out:
# (0.0, 6.0)

# %% [markdown]
# # Which production year of cars sold the most?

# %%
caryear = csales.loc[csales['year'] >= 2000]
caryear['year'].value_counts().sort_index().plot.line()
plt.title("Production Year wise count of vehicles")      # production year wise count of vehicles
plt.ylabel('Count of vehicles')
plt.xlabel('Production Year')
# Out:
# Text(0.5, 0, 'Production Year')

# %%
sns.countplot(y='price_group',data=csales, hue='body', order=['<20K','20-39K','40-59K','60-79K','80-99K','>100K'])           
plt.title("Price Group v/s Body Type")
plt.ylabel('Price Group')
plt.xlabel('Count of vehicles');

# %% [markdown]
# # Which type of engine type car is sold most ?

# %%
sns.countplot(x='engtype', data=csales, orient='h')
plt.title("Most preferred engType used over the years")
# Out:
# Text(0.5, 1.0, 'Most preferred engType used over the years')

# %%
csales.head()
# Out:
#              car    price       body  mileage      engv engtype registration  \
# 0           Ford  15500.0  crossover       68  2.500000     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173  1.800000     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135  5.500000  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162  1.800000  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91  2.646344   Other          yes
#
#    year    model  drive price_group
# 0  2010     Kuga   full        <20K
# 1  2011  E-Class   rear      20-39K
# 2  2008   CL 550   rear      20-39K
# 3  2012    B 180  front        <20K
# 4  2013  E-Class    NaN      20-39K

# %%
plt.hist(csales['price'],10)
# Out:
# (array([9.149e+03, 3.090e+02, 7.600e+01, 2.500e+01, 7.000e+00, 5.000e+00,
#         0.000e+00, 0.000e+00, 1.000e+00, 3.000e+00]),
#  array([2.59350000e+02, 5.50134150e+04, 1.09767480e+05, 1.64521545e+05,
#         2.19275610e+05, 2.74029675e+05, 3.28783740e+05, 3.83537805e+05,
#         4.38291870e+05, 4.93045935e+05, 5.47800000e+05]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(csales['mileage'],10)

# %%
csales = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv", encoding='cp1252') 
csales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
bp1 = sns.boxplot(x='mileage', y='body', data = csales )

# %%
corr_mat = csales.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_mat, annot=True, cmap='viridis')

# %%
sns.regplot(csales['price'],csales['year'])

# %% [markdown]
# # Sorting price in ascending order

# %%
csales_sort_sales = csales.sort_values(by='price' , ascending=False)
csales_sort_sales.head()
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 7621        Bentley  547800.0      sedan        0  6.75  Petrol          yes
# 7914        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 1611        Bentley  499999.0  crossover        0  6.00  Petrol          yes
# 4134        Bentley  449999.0  crossover        0  6.00  Petrol          yes
# 4325  Mercedes-Benz  300000.0      sedan       68  6.00  Petrol          yes
#
#       year     model drive
# 7621  2016  Mulsanne  rear
# 7914  2016  Bentayga  full
# 1611  2016  Bentayga  full
# 4134  2016  Bentayga  full
# 4325  2011     S 600   NaN

# %% [markdown]
# # Sorting mileage in ascending order

# %%
csales_sort_mileage = csales.sort_values(by='mileage', ascending=False)
csales_sort_mileage.head()
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 6857            VAZ    750.0      sedan      999   1.3  Petrol          yes
# 7845           Fiat   4000.0        van      999   2.5  Diesel          yes
# 2602  Mercedes-Benz  68700.0  crossover      980   3.0  Diesel          yes
# 334          Toyota  36000.0  crossover      940   NaN   Other          yes
# 7970            ZAZ   1600.0      sedan      930   1.2     Gas          yes
#
#       year             model  drive
# 6857  1984              2106   rear
# 7845  1998      Ducato ïàññ.  front
# 2602  2013            GL 350   full
# 334   2009  Land Cruiser 200    NaN
# 7970  2006      1103 Ñëàâóòà  front

# %%
num_bins = 50
plt.hist(csales['price'], num_bins)
# Out:
# (array([5.547e+03, 2.404e+03, 6.720e+02, 3.400e+02, 1.860e+02, 1.130e+02,
#         8.000e+01, 5.000e+01, 3.100e+01, 3.800e+01, 3.200e+01, 1.900e+01,
#         1.100e+01, 4.000e+00, 8.000e+00, 8.000e+00, 6.000e+00, 5.000e+00,
#         6.000e+00, 0.000e+00, 4.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 3.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([     0.,  10956.,  21912.,  32868.,  43824.,  54780.,  65736.,
#          76692.,  87648.,  98604., 109560., 120516., 131472., 142428.,
#         153384., 164340., 175296., 186252., 197208., 208164., 219120.,
#         230076., 241032., 251988., 262944., 273900., 284856., 295812.,
# ...

# %%
csales.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x130925d10>,
# ...
#       dtype=object)

# %% [markdown]
# # List out top 10 car brands on sale?

# %%
csales.car.value_counts().head(10).plot.bar()
plt.title("Top 10 car brands on sale")
# Out:
# Text(0.5, 1.0, 'Top 10 car brands on sale')

# %%
sns.pairplot(csales, hue='engType', palette="viridis", height=3)

# %% [markdown]
# # What is the maximum number of registered cars?

# %%
csales.sort_values(['car','model','body','mileage','year'])

df = csales.groupby('year')['registration'].value_counts().sort_values(ascending=False)
df = pd.DataFrame(df)
df.rename(columns={'registration': 'RegCounts'}, inplace=True)
df.reset_index(inplace=True)
display(df.head())
sns.lineplot(data=df, x='year', y='RegCounts', hue='registration')
#sns.scatterplot(data=df, x='year', y='RegCounts', hue='registration')
plt.title("Years group having max sale/registration")
# Out:
#    year registration  RegCounts
# 0  2008          yes       1150
# 1  2007          yes        915
# 2  2012          yes        756
# 3  2011          yes        691
# 4  2013          yes        642
# Text(0.5, 1.0, 'Years group having max sale/registration')

# %%
csales = pd.read_csv("https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Projects/car_sales.csv", encoding='cp1252') 
csales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# # Which cars are sold highest and lowest based  on wheel drive type?

# %%
csales['drive'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("Drive Type pie diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Drive Type');

# %%
csales.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %% [markdown]
# # How does price is relate to mileage and production year of the car?

# %%
csales[csales['price'] < 100000 ].plot.scatter(x='price', y='mileage')
plt.title("Price v/s Mileage")
plt.ylabel('Mileage')
plt.xlabel('Price');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
csales[csales['price'] <= 300000].plot.scatter(x='year',y='price')
plt.title("Price v/s Production Year")
plt.ylabel('Price')
plt.xlabel('Year');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
csales[csales['price'] < 100000 ].plot.scatter(x='price', y='mileage')
plt.title("Price v/s Mileage")
plt.ylabel('Mileage')
plt.xlabel('Price');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
csales[csales['price'] <= 300000].plot.scatter(x='year',y='price')
plt.title("Price v/s Production Year")
plt.ylabel('Price')
plt.xlabel('Year');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
sns.lineplot(data=csales[csales.year >= 2010], y='price', x='year', hue='drive')
plt.title("year - price lineplot (2010 - 2016)")
# Out:
# Text(0.5, 1.0, 'year - price lineplot (2010 - 2016)')

# %%
csales = pd.DataFrame({'col1': [1, 2], 'col2': [3, 4]})
csales.shape
# Out:
# (2, 2)

# %%
# grouping of engV  
(pd.cut(csales['engV'],[0,0.51,1.51,2.51,3.51,100], 
        labels = ['<=0.5','0.51-1.50','1.51-2.50','2.51-3.50','>3.51']).value_counts() / len(csales)*100).plot.bar()    
plt.title("Engine Volume (engV) Bar Diagram") 
plt.ylabel('% of vehicles')
plt.xlabel('Engine Volume Group');

# %% [markdown]
# # Which price segment cars sold the most ?

# %%
(csales['price'].value_counts() / len(csales) *100).plot.bar()
plt.title("Price bar diagram")
plt.ylabel('% of vehicles')
plt.xlabel('Price');

# %% [markdown]
# # 5.Conclusion

# %% [markdown]
# * In this dataset We have total 9374 observations after removing duplicate records.
#
# * "Front" drive type segment cars are the highest sold cars, because most of the cars of this segment falls in lower price range.
#
# * 80% of total cars sold in the price range of 200 to 20000 with body type as "Sedan", drive type as "Front" and engine type as "Petrol", because the middle class families preferred low price cars with Sedan body and Petrol engine type.
# * "Mercedes-Benz" is the leading brand in higher price segment cars.
# * Majority of the higher price range cars sold with body type as "Crossover", drive type as "Full" and engine type as "Diesel".
# * All body segment of cars have more average price for "Full" drive type cars compare to other drive type cars.
#
# * We have also observed that lower price segment car has higher mileage and higher price segment car has lower mileage.
# * Majority of the cars with production year 2008 or later were registered in Ukrain sold in price of 50000 or lower.
# * Production year 2008 and 2012 cars are the highest sold cars.
# * Price has positive correlation with engine volume and production year and negatively correlation with mileage.
# * Production year has negative correlation with mileage and engine volume.
